# %% [markdown]
# # <font color ="red"> INTRO TO PYTHON

# %% [markdown]
# Burada Python ve Pandas çalışacağım.

# %% [markdown]
# ## Değişken Tanımlama

# %%
a=3
b=4
c=a*b

# %%
print(c*3)
# Out:
# 36

# %%
"Deneme" * 100
# Out:
# '...'

# %%
for i in range(10):
    print("Deneme")
# Out:
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme
# Deneme

# %% [markdown]
# ## Veri Tipleri

# %%
#1-String: Yazı metin text, tek-çift-üç tırnak şeklinde kullanılıyor 
#2-Integer: Tam Sayı
#3-Float: Ondalıklı sayı

# %%
d="test"
d='test'
d='''test'''
d="O'Connor"
d='''Ali'nin babası dediki "Merhaba"'''

# %% [markdown]
# ## Listeler

# %%
list1=[1,2,5,9,'Ali','Ahmet',"Ayşe"]

# %% [markdown]
# ## Dictionary

# %%
sozluk={'key' : 'açıklama'}

# %% [markdown]
# ## Fonksiyonlar

# %%
Fiyat=[25,50,100,125]

# %%
def vergi(x):
    return x*1.6

# %%
vergi(100)
# Out:
# 160.0

# %%
for i in Fiyat:
    print(vergi(i))
# Out:
# 40.0
# 80.0
# 160.0
# 200.0

# %% [markdown]
# # Operatörler

# %%
# Aritmetik Operatörler + - * /
# Modüler %
# Üs Alma x**2
# Mantıksal Operatörler < > == != and or | &

# %%
import pandas as pd

# %%
#dataframe df - tablo
df=pd.read_csv('train.csv')

# %%
# tablodaki ilk 5 satır
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# tablodaki satır ve sütun sayısı
df.shape
# Out:
# (891, 12)

# %%
# tablodaki son 5 satır
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# tablodaki tüm verilerin grafiği 
df.plot()
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag
# <Axes: >

# %%
# tablodaki rakam sütunların adet ort sapmalar vs 
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.corr(numeric_only=True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
# sutündaki uniq değer adedi
df['Gender'].nunique()
# Out:
# 2

# %%
# sutündaki değerlerin adedi
df['Gender'].value_counts()
# Out:
# Gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
# sutündaki değerlerin dağılımı
df['Gender'].value_counts(normalize=True)
# Out:
# Gender
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %%
#Fonksiyonlarda () kullanılır hesaplama için

# %%
df[df['Age']<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df.columns=df.columns.str.upper()

# %%
df.head()
# Out:
#    PASSENGERID  SURVIVED  PCLASS  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 NAME  GENDER   AGE  SIBSP  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    PARCH            TICKET     FARE CABIN EMBARKED
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df=pd.read_ecxel('sales-funnel.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 df=pd.read_ecxel('sales-funnel.xlsx')
#
# AttributeError: module 'pandas' has no attribute 'read_ecxel'

# %%
pip  install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_ecxel('sales-funnel.xlsx')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 df=pd.read_ecxel('sales-funnel.xlsx')
#
# AttributeError: module 'pandas' has no attribute 'read_ecxel'

# %%
df = pd.read_excel('sales-funnel.xlsx')

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %%
df=pd.read_xml('catalog.xml')

# %%
df.head()
# Out:
#                 COMMON               BOTANICAL ZONE         LIGHT  PRICE  \
# 0            Bloodroot  Sanguinaria canadensis    4  Mostly Shady  $2.44
# 1            Columbine    Aquilegia canadensis    3  Mostly Shady  $9.37
# 2       Marsh Marigold        Caltha palustris    4  Mostly Sunny  $6.81
# 3              Cowslip        Caltha palustris    4  Mostly Shady  $9.90
# 4  Dutchman's-Breeches     Dicentra cucullaria    3  Mostly Shady  $6.44
#
#    AVAILABILITY
# 0         31599
# 1         30699
# 2         51799
# 3         30699
# 4         12099

# %%
import pandas as pd

# %%
df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File /opt/anaconda3/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'html5lib'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
pip install html5lib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 1.6 MB/s eta 0:00:00 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
# ...

# %%
import pandas as pd
import sys
import io

# Varsayılan kodlamayı utf-8 olarak ayarla
sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')

df = pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]

print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[177], line 6
#       3 import io
#       5 # Varsayılan kodlamayı utf-8 olarak ayarla
# ----> 6 sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')
#       8 df = pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]
#      10 print(df)
#
# AttributeError: 'OutStream' object has no attribute 'buffer'

# %%
import pandas as pd
import locale

# Ortamın dil ayarlarını değiştirme
locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')

df = pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]

print(df)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[179], line 7
#       4 # Ortamın dil ayarlarını değiştirme
#       5 locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# ----> 7 df = pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi')[0]
#       9 print(df)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
# ...

# %%
df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi#Veri')[0]
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[181], line 1
# ----> 1 df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi#Veri')[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
# ...

# %%
import pandas as pd
import locale

# %%
import pandas as pd
import locale
import sys
import io

# %%
df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi#Veri')[0]
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[187], line 1
# ----> 1 df=pd.read_html('https://tr.wikipedia.org/wiki/Türkiye_ekonomisi#Veri')[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
#    1241     flavor=flavor,
# ...

# %%
df=pd.read_html('https://tr.wikipedia.org/wiki/Super_Lig_tum_zamanlarin_puan_durumu')[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df=pd.read_html('https://tr.wikipedia.org/wiki/Super_Lig_tum_zamanlarin_puan_durumu')[0]
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1224 if isinstance(io, str) and not any(
#    1225     [
#    1226         is_file_like(io),
#    (...)
#    1230     ]
#    1231 ):
#    1232     warnings.warn(
#    1233         "Passing literal html to 'read_html' is deprecated and "
#    1234         "will be removed in a future version. To read from a "
#    (...)
#    1237         stacklevel=find_stack_level(),
#    1238     )
# -> 1240 return _parse(
# ...

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/Bundesliga')[1]

# %%
df
# Out:
#                         Club Position in 2022–23 First Bundesliga season  \
# 0               FC Augsburgb                15th                 2011–12
# 1          Bayer Leverkusenb                 6th                 1979–80
# 2             Bayern Munichb                 1st                 1965–66
# 3                 VfL Bochum                14th                 1971–72
# 4         Borussia Dortmunda                 2nd                 1963–64
# 5   Borussia Mönchengladbach                10th                 1965–66
# 6               Darmstadt 98          2nd (2. B)                 1978–79
# 7       Eintracht Frankfurta                 7th                 1963–64
# 8                SC Freiburg                 5th                 1993–94
# 9          1. FC Heidenheimb          1st (2. B)                 2023–24
# 10           TSG Hoffenheimb                12th                 2008–09
# 11               1. FC Kölna                11th                 1963–64
# ...

# %%
df.to_excel('puan.xlsx')

# %%
df
# Out:
#                         Club Position in 2022–23 First Bundesliga season  \
# 0               FC Augsburgb                15th                 2011–12
# 1          Bayer Leverkusenb                 6th                 1979–80
# 2             Bayern Munichb                 1st                 1965–66
# 3                 VfL Bochum                14th                 1971–72
# 4         Borussia Dortmunda                 2nd                 1963–64
# 5   Borussia Mönchengladbach                10th                 1965–66
# 6               Darmstadt 98          2nd (2. B)                 1978–79
# 7       Eintracht Frankfurta                 7th                 1963–64
# 8                SC Freiburg                 5th                 1993–94
# 9          1. FC Heidenheimb          1st (2. B)                 2023–24
# 10           TSG Hoffenheimb                12th                 2008–09
# 11               1. FC Kölna                11th                 1963–64
# ...

# %%
pip install gtts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS

# %%
text="bunu yapay zeka dersinde öğrenerek yazdım"
kayit=gTTS(text=text,lang='tr',slow=False)
kayit.save('robot.mp3')
