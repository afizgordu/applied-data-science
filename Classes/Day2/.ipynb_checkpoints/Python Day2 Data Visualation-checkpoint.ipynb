# %% [markdown]
# # EDA - Data Visualazation

# %% [markdown]
# Bugünün dersini burada işleyeceğiz

# %%
a=3
b=5
c=a*b
print(c)
# Out:
# 15

# %%
a
# Out:
# 3

# %%
import pandas as pd

# %%
df=pd.read_csv('combine.csv')

# %% [markdown]
# data.gov, data.lacity.orgveya kaggle.com adresinden data indirilebilir

# %% [markdown]
# # EDA - Exploratory Data (Keşifçi Veri Analizi)

# %%
df.head() #ilk 5 satırı gösterir
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  vertical  broad  bench  \
# 0           9.0               69.0     205   0.0  ...      42.5    130     24
# 1           0.0               72.0     198   0.0  ...       0.0      0     12
# 2           0.0               72.0     221   0.0  ...      39.0    121     19
# 3           1.0               73.0     227   0.0  ...      36.0    121     24
# 4           8.0               68.0     180   0.0  ...      34.0    121     13
#
#    round        college  pick  pickround  picktotal  wonderlic  nflgrade
# ...

# %%
df.shape # satır sayısı, sütun sayısını gösterir
# Out:
# (4947, 26)

# %%
df.info() #bilgi verir
# object = category variable String metin yazı text
# int = tam sayı
# float = ondalıklı sayı (pythonda virgül yerine nokta 1,5 yerine 1.5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4947 entries, 0 to 4946
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               4947 non-null   int64
#  1   name               4947 non-null   object
#  2   firstname          4947 non-null   object
#  3   lastname           4947 non-null   object
#  4   position           4947 non-null   object
#  5   heightfeet         4947 non-null   int64
#  6   heightinches       4947 non-null   float64
#  7   heightinchestotal  4947 non-null   float64
#  8   weight             4947 non-null   int64
#  9   arms               4947 non-null   float64
#  10  hands              4947 non-null   float64
#  11  fortyyd            4947 non-null   float64
#  12  twentyyd           4947 non-null   float64
#  13  tenyd              4947 non-null   float64
#  14  twentyss           4947 non-null   float64
#  15  threecone          4947 non-null   float64
# ...

# %%
df.describe() # istatistiksel verileri gösterir
# Out:
#               year   heightfeet  heightinches  heightinchestotal       weight  \
# count  4947.000000  4947.000000   4947.000000        4947.000000  4947.000000
# mean   2007.132201     5.805337      4.371437          74.035476   245.579745
# std       5.029664     0.395981      3.279223           2.614778    45.639366
# min    1999.000000     5.000000      0.000000          65.000000   155.000000
# 25%    2003.000000     6.000000      2.000000          73.000000   208.000000
# 50%    2007.000000     6.000000      4.000000          74.000000   237.000000
# 75%    2012.000000     6.000000      6.000000          76.000000   289.000000
# max    2015.000000     6.000000     11.875000          82.000000   386.000000
#
#               arms        hands      fortyyd     twentyyd        tenyd  \
# count  4947.000000  4947.000000  4947.000000  4947.000000  4947.000000
# mean      7.640243     2.252426     4.610386     0.073734     0.129149
# ...

# %%
df.isnull().sum() #hangi sütunda kaç null var gösterir
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college              1470
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
df2=df.describe()

# %%
df2.to_excel('istatistik-tablo.xlsx')

# %%
df['college']=df['college'].fillna('okuyor') #boşlukları doldur

# %%
df.isnull().sum()
# Out:
# year                    0
# name                    0
# firstname               0
# lastname                0
# position                0
# heightfeet              0
# heightinches            0
# heightinchestotal       0
# weight                  0
# arms                    0
# hands                   0
# fortyyd                 0
# twentyyd                0
# tenyd                   0
# twentyss                0
# threecone               0
# vertical                0
# broad                   0
# bench                   0
# round                   0
# college                 0
# pick                 1791
# pickround               0
# picktotal               0
# wonderlic               0
# nflgrade                0
# dtype: int64

# %%
df.sample(20) # tablodan rastgele 20 örnek
# Out:
#       year               name firstname   lastname position  heightfeet  \
# 1758  2010       Corey Peters     Corey     Peters       DT           6
# 4608  1999   Justin Burroughs    Justin  Burroughs       OC           6
# 4344  2000  Giovanni Carmazzi  Giovanni   Carmazzi       QB           6
# 1058  2012        Mike Harris      Mike     Harris       CB           5
# 4740  1999      Paris Johnson     Paris    Johnson       SS           6
# 697   2013     Tank Carradine      Tank  Carradine       DE           6
# 4240  2001        Mike Roberg      Mike     Roberg       TE           6
# 1938  2009       Josh Freeman      Josh    Freeman       QB           6
# 2572  2007       Uche Nwaneri      Uche    Nwaneri       OG           6
# 3111  2005     Chris Kemoeatu     Chris   Kemoeatu       OG           6
# 2966  2005         David Baas     David       Baas       OG           6
# 2594  2007        Jerard Rabb    Jerard       Rabb       WR           6
# ...

# %%
df[df['college']=='okuyor'] #Data Munging - Boş verileri doldurma
# Out:
#       year             name firstname  lastname position  heightfeet  \
# 660   2013       Zach Allen      Zach     Allen       OG           6
# 662   2013    C.J. Anderson      C.J.  Anderson       RB           5
# 663   2013      Ziggy Ansah     Ziggy     Ansah       DE           6
# 668   2013     Alvin Bailey     Alvin    Bailey       OG           6
# 673   2013     Chris Barker     Chris    Barker       OG           6
# ...    ...              ...       ...       ...      ...         ...
# 4930  1999  Gerald Williams    Gerald  Williams       WR           6
# 4931  1999    Parc Williams      Parc  Williams      OLB           6
# 4936  1999        Brad Winn      Brad      Winn       OG           6
# 4940  1999        Mark Word      Mark      Word      OLB           6
# 4941  1999   Anthony Wright   Anthony    Wright       QB           6
#
#       heightinches  heightinchestotal  weight    arms  ...  vertical  broad  \
# ...

# %%
df['weight'].min() #en düşük ağırlık
# Out:
# 155

# %%
df['weight'].min(),df['weight'].max(),df['weight'].mean()
# Out:
# (155, 386, 245.57974530018194)

# %%
df['weight'].median() #orta değer
# Out:
# 237.0

# %%
df['weight'].mode() #en çok tekrar eden
# Out:
# 0    211
# Name: weight, dtype: int64

# %%
df['weight'].mode()[0]
# Out:
# 211

# %%
isim='Ahmet Faruk İzgördü'

# %%
isim[0],isim[6],isim[-7]
# Out:
# ('A', 'F', 'İ')

# %%
del df['pick'] #sütunu silmek için

# %%
df.head()
# Out:
#    year            name firstname   lastname position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah       RB           5
# 1  2015  Nelson Agholor    Nelson    Agholor       WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi       RB           6
# 3  2015  Kwon Alexander      Kwon  Alexander      OLB           6
# 4  2015    Mario Alford     Mario     Alford       WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 0           9.0               69.0     205   0.0  ...       6.79      42.5
# 1           0.0               72.0     198   0.0  ...       0.00       0.0
# 2           0.0               72.0     221   0.0  ...       7.10      39.0
# 3           1.0               73.0     227   0.0  ...       7.14      36.0
# 4           8.0               68.0     180   0.0  ...       6.64      34.0
#
#    broad  bench  round        college  pickround  picktotal  wonderlic  \
# ...

# %%
#df.drop(['pick'],axis=1) axis=1 sütun siler, axis=0  satır siler

# %%
df['college'].value_counts() #sütundaki verilerin adetleri
# Out:
# college
# okuyor                   1470
# Georgia                    81
# Florida                    80
# USC                        77
# Alabama                    75
#                          ...
# Chadron State               1
# East Central Oklahoma       1
# Jacksonville State          1
# Georgia State               1
# Fort Valley State           1
# Name: count, Length: 285, dtype: int64

# %%
df.corr(numeric_only=True) #hangi sütunun hangi sütunla ne kadar ilişkili olduğunu gösterir
# Out:
#                        year  heightfeet  heightinches  heightinchestotal  \
# year               1.000000   -0.039052      0.011510          -0.056533
# heightfeet        -0.039052    1.000000     -0.850192           0.751042
# heightinches       0.011510   -0.850192      1.000000          -0.290924
# heightinchestotal -0.056533    0.751042     -0.290924           1.000000
# weight            -0.023865    0.494802     -0.152829           0.707528
# arms               0.449489   -0.001362     -0.012845          -0.018585
# hands              0.449315   -0.003031     -0.011516          -0.019951
# fortyyd           -0.267533    0.106292     -0.015781           0.173372
# twentyyd           0.018285   -0.023082      0.013885          -0.024534
# tenyd              0.231727   -0.026584      0.011606          -0.033756
# twentyss          -0.065355    0.072599     -0.013882           0.114524
# threecone          0.555709   -0.031228      0.011585          -0.042220
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True) #annot tablo içindeki sayıları veriyor
# Out:
# <Axes: >

# %%
df['position'].unique() #sütundaki uniq değerleri gösterir
# Out:
# array(['RB', 'WR', 'OLB', 'FS', 'DE', 'TE', 'ILB', 'DT', 'P', 'QB', 'OG',
#        'OT', 'K', 'FB', 'SS', 'LS', 'CB', 'C', 'NT', 'OC'], dtype=object)

# %%
df['position'].nunique() #sütundaki uniq değer adedi
# Out:
# 20

# %%
df['position']=df['position'].replace(['RB','QB'],['Running Back','Quarter Back'])  #replace(['neyi','neyi'],['neyle','neyle'])

# %%
df.head()
# Out:
#    year            name firstname   lastname      position  heightfeet  \
# 0  2015  Ameer Abdullah     Ameer   Abdullah  Running Back           5
# 1  2015  Nelson Agholor    Nelson    Agholor            WR           6
# 2  2015       Jay Ajayi       Jay      Ajayi  Running Back           6
# 3  2015  Kwon Alexander      Kwon  Alexander           OLB           6
# 4  2015    Mario Alford     Mario     Alford            WR           5
#
#    heightinches  heightinchestotal  weight  arms  ...  threecone  vertical  \
# 0           9.0               69.0     205   0.0  ...       6.79      42.5
# 1           0.0               72.0     198   0.0  ...       0.00       0.0
# 2           0.0               72.0     221   0.0  ...       7.10      39.0
# 3           1.0               73.0     227   0.0  ...       7.14      36.0
# 4           8.0               68.0     180   0.0  ...       6.64      34.0
#
#    broad  bench  round        college  pickround  picktotal  wonderlic  \
# ...

# %% [markdown]
# ### Data Visualazation

# %%
import numpy as np #lineer cebir paketi matirxler, matrix çarpımı, vector uzayları matematik vs

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
