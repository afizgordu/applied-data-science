# %% [markdown]
# # DAY7 - STYLECLOUD

# %% [markdown]
# Burada Day7 ye ait Style Cloud çalışmalarımı not alacağım.

# %%
pip install --upgrade stylecloud matplotlib
# Out:
# Requirement already satisfied: stylecloud in /opt/anaconda3/lib/python3.12/site-packages (0.5.1)
# Collecting stylecloud
#   Using cached stylecloud-0.5.2-py3-none-any.whl
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.8.4)
# Collecting matplotlib
#   Downloading matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: wordcloud in /opt/anaconda3/lib/python3.12/site-packages (from stylecloud) (1.9.3)
# Requirement already satisfied: icon-font-to-png in /opt/anaconda3/lib/python3.12/site-packages (from stylecloud) (0.4.1)
# Requirement already satisfied: palettable in /opt/anaconda3/lib/python3.12/site-packages (from stylecloud) (3.3.3)
# Requirement already satisfied: fire in /opt/anaconda3/lib/python3.12/site-packages (from stylecloud) (0.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.12/site-packages (from fire->stylecloud) (2.4.0)
# Requirement already satisfied: requests>=2.12.5 in /opt/anaconda3/lib/python3.12/site-packages (from icon-font-to-png->stylecloud) (2.32.2)
# Requirement already satisfied: tinycss>=0.4 in /opt/anaconda3/lib/python3.12/site-packages (from icon-font-to-png->stylecloud) (0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2024.7.4)
# Downloading matplotlib-3.9.1-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 3.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: matplotlib, stylecloud
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
#       Successfully uninstalled matplotlib-3.8.4
#   Attempting uninstall: stylecloud
#     Found existing installation: stylecloud 0.5.1
#     Uninstalling stylecloud-0.5.1:
#       Successfully uninstalled stylecloud-0.5.1
# Successfully installed matplotlib-3.9.1 stylecloud-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
import stylecloud as sc

# %%
sc.gen_stylecloud(file_path='challenge.txt', output_name='ch.png')

# %%
from IPython.display import Image
Image('ch.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-car', 
    output_name='ch2.png')

# %%
Image('ch2.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-truck',
    background_color='grey', 
    output_name='ch3.png')

# %%
Image('ch3.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-fighter-jet',
    background_color='pink', 
    output_name='ch4.png')

# %%
Image('ch4.png')

# %%
sc.gen_stylecloud(
    file_path='challenge.txt',
    icon_name='fas fa-star-and-crescent', 
    output_name='tr.png')

# %%
Image('tr.png')
