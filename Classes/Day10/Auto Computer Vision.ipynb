# %% [markdown]
# # AUTO COMPUTER VISION

# %%
pip install cvlib
# Out:
# Requirement already satisfied: cvlib in /opt/anaconda3/lib/python3.12/site-packages (0.2.7)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (1.26.4)
# Requirement already satisfied: progressbar in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (2.5)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (2.32.2)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (8.4.0)
# Requirement already satisfied: imageio in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (2.33.1)
# Requirement already satisfied: imutils in /opt/anaconda3/lib/python3.12/site-packages (from cvlib) (0.5.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests->cvlib) (2024.7.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib
from cvlib.object_detection import draw_bbox

# %%
img=cv2.imread('cars.jpg')

# %%
plt.imshow(img);

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
label.count('car')
# Out:
# 11

# %%
label.count('person')
# Out:
# 1

# %%
img=cv2.imread('g8.jpg')

# %%
plt.imshow(img)

# %%
box,label,count=cvlib.detect_common_objects(img)

# %%
output=draw_bbox(img,box,label,count)

# %%
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
label.count('person')
# Out:
# 6

# %%
img=cv2.imread('dogs.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output);

# %%
label.count('dog')
# Out:
# 4

# %%
img=cv2.imread('mutfak.jpg')
box,label,count=cvlib.detect_common_objects(img)
output=draw_bbox(img,box,label,count)
plt.figure(figsize=(10,10))
plt.imshow(output);
