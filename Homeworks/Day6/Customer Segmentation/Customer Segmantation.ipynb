# %% [markdown]
# # CUSTOMER SEGMENTATION - CLUSTRING HOMEWORK

# %% [markdown]
# Business Objective<br>
# A company has asked its data science team to segment its customer base in order to help targeted marketing and understand their buying habits.

# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns",100)

from sklearn.linear_model import LinearRegression,SGDRegressor,Ridge,Lasso,ElasticNet
from sklearn.neighbors import KNeighborsRegressor, RadiusNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor, plot_tree, ExtraTreeRegressor
#pip install xgboost
from xgboost import XGBRegressor
from sklearn.svm import SVR

from sklearn.neural_network import MLPRegressor

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error

from sklearn.preprocessing import StandardScaler

pd.set_option("display.max_columns",120)
pd.set_option("display.max_rows",120)

# %%
#read data
df=pd.read_csv('PBL5recommendationdata.csv', encoding='latin1')

# %% [markdown]
# ### EDA - Exploratory Data Analysis

# %%
df.head()
# Out:
#    Customers.id Customers.fname Customers.lname Customers.company  \
# 0           797         Christy            Dill          Company0
# 1             3            John           Smith          Company1
# 2             3            John           Smith          Company1
# 3             4           James        Anderson               NaN
# 4             5         Abraham          Pollak          Company3
#
#    Customers.create_date  Customers.status  Customers.mailing  \
# 0             1426018724               NaN                NaN
# 1             1386089139               NaN                NaN
# 2             1386089139               NaN                NaN
# 3             1386780263               NaN                NaN
# 4             1386861599               0.0                0.0
#
#    Customers.reminders  Customers.tax_exempt  Customers.account_id  \
# 0                  NaN                   NaN                   NaN
# 1                  NaN                   NaN                   NaN
# 2                  NaN                   NaN                   NaN
# 3                  NaN                   NaN                   NaN
# 4                  NaN                   NaN                   NaN
#
#    Customers.sales_rep  Customers.rewards  Customers.profile_id  \
# 0                  NaN                NaN                   NaN
# 1                  NaN                NaN                   NaN
# 2                  NaN                NaN                   NaN
# 3                  NaN                NaN                   NaN
# 4                  NaN                NaN                   NaN
#
#    Customers.last_modified  Customers.customer_type  Orders.id  \
# 0               1437764306                      0.0       3758
# 1               1437764354                      0.0         23
# 2               1437764354                      0.0       9531
# 3               1437762646                      0.0         29
# 4               1437764316                      0.0         30
#
#    Orders.customer_id Orders.fname Orders.lname Orders.company  \
# 0                 797      Christy         Dill       Company0
# 1                   3         John        Smith       Company1
# 2                   3         John        Smith       Company1
# 3                   4        James     Anderson            NaN
# 4                   5      Abraham       Pollak       Company3
#
#   Orders.order_number  Orders.reorder_id Orders.external_source  \
# 0                3758                NaN                    NaN
# 1                  23                NaN                    NaN
# 2                9531                NaN                    NaN
# 3                  29                NaN                   Ebay
# 4                  30                NaN                    NaN
#
#    Orders.external_id Orders.currency  Orders.sales_rep  Orders.subtotal  \
# 0                 NaN             USD               NaN            57.20
# 1                 NaN             USD               NaN            20.00
# 2                 NaN             USD               NaN            68.78
# 3                 NaN             USD               NaN            19.56
# 4                 NaN             USD               NaN            36.05
#
#    Orders.tax  Orders.shipping  Orders.coupon_id  Orders.coupon_amount  \
# 0         0.0             9.95              13.0                  2.86
# 1         NaN             9.99               NaN                   NaN
# 2         0.0             9.95               NaN                   NaN
# 3         0.0             9.95               NaN                   NaN
# 4         NaN             9.95               NaN                   NaN
#
#    Orders.gift_id  Orders.gift_amount Orders.fee_name  Orders.fee_amount  \
# 0             NaN                 NaN             NaN                NaN
# 1             NaN                 NaN             NaN                NaN
# 2             NaN                 NaN             NaN                NaN
# 3             NaN                 NaN             NaN               0.04
# 4             NaN                 NaN             NaN                NaN
#
#   Orders.discount_name  Orders.discount_amount  Orders.total  \
# 0                  NaN                     NaN         64.29
# 1                  NaN                     NaN         29.99
# 2                  NaN                     NaN         78.73
# 3                  NaN                     NaN         29.55
# 4                  NaN                     NaN         46.00
#
#    Orders.balance_due Orders.shipping_carrier Orders.shipping_method  \
# 0                 NaN                   fedex              11|Ground
# 1                 NaN                   fedex              11|Ground
# 2                 NaN                  manual    0|Standard Shipping
# 3                 NaN                     NaN              11|Ground
# 4                 NaN                   fedex              11|Ground
#
#    Orders.shipping_trans  Orders.shipping_flags  Orders.weight  \
# 0                    NaN                    NaN            NaN
# 1                    NaN                    NaN            NaN
# 2                    NaN                    NaN            NaN
# 3                    NaN                    NaN            NaN
# 4                    NaN                    NaN            NaN
#
#   Orders.tracking  Orders.payment_status  Orders.payment_date  \
# 0      5.7204E+14                    3.0         1.426019e+09
# 1     1.28597E+14                    3.0         1.386090e+09
# 2             NaN                    3.0         1.449604e+09
# 3     7.96468E+14                    3.0         1.386780e+09
# 4     6.87398E+14                    3.0         1.386862e+09
#
#   Orders.payment_user Orders.payment_type Orders.payment_method  \
# 0                 NaN       authorize.net                   NaN
# 1                 NaN       authorize.net                   NaN
# 2           genlee166       authorize.net                   NaN
# 3                 NaN                 NaN           Credit Card
# 4                 NaN                 NaN           Credit Card
#
#    Orders.payment_amount  Orders.purchase_order Orders.payment_id  \
# 0                  64.29                    NaN        6993607863
# 1                  29.99                    NaN                 0
# 2                  78.73                    NaN                 0
# 3                  29.55                    NaN               NaN
# 4                  46.00                    NaN               NaN
#
#   Orders.payment_code  Orders.payment_ref  Orders.status  Orders.placed_date  \
# 0              510142                 NaN              1          1426019099
# 1                   0                 NaN              1          1386090455
# 2                   0                 NaN              3          1449603652
# 3                 NaN                 NaN              1          1386780263
# 4                 NaN                 NaN              1          1386861599
#
#    Orders.updated_date  Orders.shipped_date              Orders.comments  ...  \
# 0         1.438868e+09         1.426101e+09                          NaN  ...
# 1         1.440529e+09         1.386103e+09                          NaN  ...
# 2         1.450213e+09                  NaN                   test order  ...
# 3         1.440529e+09         1.386800e+09  ebay order\rpaid by pay pal  ...
# 4         1.440529e+09         1.386876e+09                          NaN  ...
#
#   Products.quickbooks_id  Products.qb_edit_sequence  \
# 0    8000064C-1434298761               1.450325e+09
# 1    80008C35-1438901283               1.450322e+09
# 2    800087BB-1438898332               1.450321e+09
# 3    8000065E-1434298780               1.450323e+09
# 4    80008B12-1438900627               1.450323e+09
#
#    Products.price_break_type  Products.price_breaks  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
#
#                  Products.short_description  \
# 0             ROLLATOR,BASIC,STEEL,6",GREEN
# 1   BAG,DRAINAGE,UROLOGY,2000ML,ANTI REFLUX
# 2  GLOVE,EXAM,NITRILE,BLUE,FINGRTIP,TXT,XXL
# 3           BASKET,WALKER,FOR 2 BUTTON WALK
# 4        DEVICE,TENS UNIT,TENS 1000,DUAL CH
#
#                            Products.long_description  Products.websites  \
# 0  <ul><li>  Classically designed, value priced</...                NaN
# 1  <ul><li>  Only Medline drain bags have a slide...                NaN
# 2  <ul><li> SensiCare&reg; nitrile exam gloves fe...                NaN
# 3  <ul><li> This wire basket attaches to almost a...                NaN
# 4  <ul><li> The TENS 3000<sup>TM</sup> analog uni...                NaN
#
#    Products.video  Products.audio  \
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
#
#                                   Products.seo_title  \
# 0  Basic Lightweight Rollators For Adults, With S...
# 1           Urinary Drain Bags | MEDLINE - DYNC1674H
# 2  Nitrile Exam Gloves, Blue, XX-Large | MEDLINE ...
# 3  Basket for 2-Button Walkers | MEDLINE - MDS866...
# 4  TENS 3000 Analog Unit | ROSCOE MEDICAL INC - M...
#
#    Products.seo_description Products.seo_keywords  Products.seo_header  \
# 0                       NaN                   NaN                  NaN
# 1                       NaN                   NaN                  NaN
# 2                       NaN                   NaN                  NaN
# 3                       NaN                   NaN                  NaN
# 4                       NaN                   NaN                  NaN
#
#   Products.seo_footer                                   Products.seo_url  \
# 0                 NaN  Basic-Rollators-For-Adults-With-Seat-Green-6-W...
# 1                 NaN                             Urinary-Drain-Bags0000
# 2                 NaN          SensiCare-Nitrile-Exam-GlovesBlueXX-Large
# 3                 NaN                      Basket-for-2-Button-Walkers-2
# 4                 NaN                                         Tens-Units
#
#    Products.seo_category  Products.unit  Products.packaging  \
# 0                    0.0             EA       1 Each / Each
# 1                    0.0             EA       1 Each / Each
# 2                    0.0             CS     800 Each / Case
# 3                    0.0             EA       1 Each / Each
# 4                    0.0             EA       1 Each / Each
#
#    Products.display_packaging  Products.multiple  Products.length  \
# 0                         NaN               1 EA              NaN
# 1                         NaN               1 EA              NaN
# 2                         NaN               1 CS              NaN
# 3                         NaN               1 EA              NaN
# 4                         NaN               1 EA              NaN
#
#    Products.width  Products.height  Products.rx  Products.latex  Products.upc  \
# 0             NaN              NaN          NaN             NaN           NaN
# 1             NaN              NaN           Rx             Yes           NaN
# 2             NaN              NaN          NaN             NaN           NaN
# 3             NaN              NaN          NaN             Yes  8.019675e+10
# 4             NaN              NaN           Rx             NaN           NaN
#
#   Products.msds_link  Products.msds_label  \
# 0                NaN                  NaN
# 1                NaN                  NaN
# 2                NaN                  NaN
# 3                NaN                  NaN
# 4                NaN                  NaN
#
#                                    Products.lit_link  \
# 0                                                NaN
# 1  https://medline360.medline.com:443/irj/servlet...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                      Products.lit_label  \
# 0                                   NaN
# 1  508f2d75-582e-2e10-2eab-d83980a9b1d0
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#                                       Products.hcpcs  Products.case_qty  \
# 0                                       E0149 +E0156                1.0
# 1                                              A4357                1.0
# 2  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION              800.0
# 3                                              A9270                1.0
# 4                                              E0730                1.0
#
#    Products.markup  Products.override_markup                   Products.notes  \
# 0              NaN                       0.0                              NaN
# 1              NaN                       0.0  OFF sale cause it is an RX item
# 2              NaN                       0.0                              NaN
# 3              NaN                       0.0                              NaN
# 4              NaN                       0.0  OFF sale cause it is an RX item
#
#    Products.import_flags  Products.map_price  Products.features_title  \
# 0                  136.0                 NaN                      NaN
# 1                    0.0                 NaN                      NaN
# 2                    NaN                 NaN                      NaN
# 3                    NaN                 NaN                      NaN
# 4                    NaN                 NaN                      NaN
#
#    Products.warranty  Products.hygienic  Products.default_quantity  \
# 0                NaN                0.0                        NaN
# 1                NaN                0.0                        NaN
# 2                NaN                NaN                        NaN
# 3                NaN                NaN                        NaN
# 4                NaN                NaN                        NaN
#
#    Products.user_size Products.assembly Products.installation  \
# 0                 NaN               NaN                   NaN
# 1                 NaN               NaN                   NaN
# 2                 NaN               NaN                   NaN
# 3                 NaN               NaN                   NaN
# 4                 NaN               NaN                   NaN
#
#   Products.shipping_length Products.shipping_width Products.shipping_height  \
# 0                    24.80                    7.50                    30.40
# 1                     8.00                    7.00                     1.50
# 2                    13.23                   10.04                    10.24
# 3                    10.60                    7.80                    18.50
# 4                     8.50                    2.75                    12.00
#
#    Products.shipping_weight Products.handling_time  Products.rotation_link  \
# 0                       NaN                    NaN                     NaN
# 1                       NaN                    NaN                     NaN
# 2                       NaN                    NaN                     NaN
# 3                       NaN                    NaN                     NaN
# 4                       NaN                    NaN                     NaN
#
#   Products.google_shopping_label  Products.product_option    Products.size  \
# 0                            NaN                      NaN              NaN
# 1                            NaN                      NaN              NaN
# 2                            NaN                      NaN  2 x Extra large
# 3                            NaN                      NaN              NaN
# 4                            NaN                      NaN              NaN
#
#   Products.material Products.arm_style  Products.leg_style  \
# 0               NaN                NaN                 NaN
# 1               NaN                NaN                 NaN
# 2           Nitrile                NaN                 NaN
# 3               NaN                NaN                 NaN
# 4               NaN                NaN                 NaN
#
#    Products.seat_size Products.family_id Products.saved_status  \
# 0                 NaN            PF61071                   0.0
# 1                 NaN            PF02132                   NaN
# 2                 NaN            PF00342                   0.0
# 3                 NaN            PF04970                   NaN
# 4                 NaN            PF03045                   NaN
#
#    Products.freight_cost
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 181 columns]

# %%
df.tail()
# Out:
#       Customers.id Customers.fname Customers.lname Customers.company  \
# 4189          3730            Nora         Fontana               NaN
# 4190          3732        Kennithe          Tecora               NaN
# 4191          3733           Tinna         Randall               NaN
# 4192          3735         HALIMAH          SHAHID               NaN
# 4193          3736         Michael         Kiernan               NaN
#
#       Customers.create_date  Customers.status  Customers.mailing  \
# 4189             1463408698               NaN                1.0
# 4190             1463412756               NaN                NaN
# 4191             1463413245               NaN                NaN
# 4192             1463416687               NaN                1.0
# 4193             1463418049               NaN                1.0
#
#       Customers.reminders  Customers.tax_exempt  Customers.account_id  \
# 4189                  NaN                   NaN                   NaN
# 4190                  NaN                   NaN                   NaN
# 4191                  NaN                   NaN                   NaN
# 4192                  NaN                   NaN                   NaN
# 4193                  NaN                   NaN                   NaN
#
#       Customers.sales_rep  Customers.rewards  Customers.profile_id  \
# 4189                  NaN                NaN                   NaN
# 4190                  NaN                NaN                   NaN
# 4191                  NaN                NaN                   NaN
# 4192                  NaN                NaN                   NaN
# 4193                  NaN                NaN                   NaN
#
#       Customers.last_modified  Customers.customer_type  Orders.id  \
# 4189               1463408698                      0.0      17421
# 4190               1463412756                      NaN      17425
# 4191               1463413245                      NaN      17426
# 4192               1463416687                      NaN      17431
# 4193               1463418049                      0.0      17434
#
#       Orders.customer_id Orders.fname Orders.lname Orders.company  \
# 4189                3730         Nora      Fontana            NaN
# 4190                3732     Kennithe       Tecora            NaN
# 4191                3733        Tinna      Randall            NaN
# 4192                3735      HALIMAH       SHAHID            NaN
# 4193                3736      Michael      Kiernan            NaN
#
#      Orders.order_number  Orders.reorder_id Orders.external_source  \
# 4189               17421                NaN                    NaN
# 4190               17425                NaN                    NaN
# 4191               17426                NaN                    NaN
# 4192               17431                NaN                    NaN
# 4193               17434                NaN                    NaN
#
#       Orders.external_id Orders.currency  Orders.sales_rep  Orders.subtotal  \
# 4189                 NaN             USD               NaN            14.85
# 4190                 NaN             USD               NaN            39.99
# 4191                 NaN             USD               NaN          1099.00
# 4192                 NaN             USD               NaN           129.99
# 4193                 NaN             USD               NaN            24.54
#
#       Orders.tax  Orders.shipping  Orders.coupon_id  Orders.coupon_amount  \
# 4189        1.21              0.0               NaN                   NaN
# 4190        0.00              NaN               NaN                   NaN
# 4191        0.00              NaN              32.0                 109.9
# 4192        0.00              0.0               NaN                   NaN
# 4193        0.00              0.0               NaN                   NaN
#
#       Orders.gift_id  Orders.gift_amount Orders.fee_name  Orders.fee_amount  \
# 4189             NaN                 NaN             NaN                NaN
# 4190             NaN                 NaN             NaN                NaN
# 4191             NaN                 NaN             NaN                NaN
# 4192             NaN                 NaN             NaN                NaN
# 4193             NaN                 NaN             NaN                NaN
#
#      Orders.discount_name  Orders.discount_amount  Orders.total  \
# 4189                  NaN                     NaN         16.06
# 4190                  NaN                     NaN         39.99
# 4191                  NaN                     NaN        989.10
# 4192                  NaN                     NaN        129.99
# 4193                  NaN                     NaN         24.54
#
#       Orders.balance_due Orders.shipping_carrier Orders.shipping_method  \
# 4189                 NaN                     NaN                    NaN
# 4190                 NaN                     NaN                    NaN
# 4191                 NaN                     NaN                    NaN
# 4192                 NaN                     NaN                    NaN
# 4193                 NaN                     NaN                    NaN
#
#       Orders.shipping_trans  Orders.shipping_flags  Orders.weight  \
# 4189                    NaN                    NaN            NaN
# 4190                    NaN                    NaN            NaN
# 4191                    NaN                    NaN            NaN
# 4192                    NaN                    NaN            NaN
# 4193                    NaN                    NaN            NaN
#
#      Orders.tracking  Orders.payment_status  Orders.payment_date  \
# 4189             NaN                    3.0         1.463409e+09
# 4190             NaN                    1.0         1.463413e+09
# 4191             NaN                    1.0         1.463413e+09
# 4192             NaN                    3.0         1.463417e+09
# 4193             NaN                    1.0         1.463418e+09
#
#      Orders.payment_user Orders.payment_type Orders.payment_method  \
# 4189                 NaN              paypal                PayPal
# 4190               Berry       authorize.net                   NaN
# 4191               Berry       authorize.net                   NaN
# 4192                 NaN              paypal                PayPal
# 4193                 NaN       authorize.net                   NaN
#
#       Orders.payment_amount  Orders.purchase_order  Orders.payment_id  \
# 4189                  16.06                    NaN  16706988SV3261147
# 4190                  39.99                    NaN         8411514882
# 4191                 989.10                    NaN         8411549709
# 4192                 129.99                    NaN  5MR65047290164601
# 4193                  24.54                    NaN         8411928116
#
#      Orders.payment_code  Orders.payment_ref  Orders.status  \
# 4189                 NaN                 NaN              0
# 4190              159938                 NaN              0
# 4191              01466D                 NaN              5
# 4192                 NaN                 NaN              0
# 4193              04142D                 NaN              0
#
#       Orders.placed_date  Orders.updated_date  Orders.shipped_date  \
# 4189          1463408854                  NaN                  NaN
# 4190          1463412757                  NaN                  NaN
# 4191          1463413246         1.463420e+09                  NaN
# 4192          1463416694                  NaN                  NaN
# 4193          1463418095                  NaN                  NaN
#
#      Orders.comments  ... Products.quickbooks_id  Products.qb_edit_sequence  \
# 4189             NaN  ...    8000115D-1434302135               1.450324e+09
# 4190             NaN  ...    80000679-1434298813               1.450322e+09
# 4191             NaN  ...    80007477-1438230105               1.450467e+09
# 4192             NaN  ...    80002971-1434309550               1.450323e+09
# 4193             NaN  ...    800082C6-1438894943               1.450322e+09
#
#       Products.price_break_type  Products.price_breaks  \
# 4189                        NaN                    NaN
# 4190                        NaN                    NaN
# 4191                        NaN                    NaN
# 4192                        NaN                    NaN
# 4193                        NaN                    NaN
#
#                    Products.short_description  \
# 4189  BAG,EMESIS,SICKNESS CLEAN-UP,CLEAN SACK
# 4190                           BAR,BED ASSIST
# 4191                                      NaN
# 4192    ROLLATOR, X-WIDE,HEAVY DUTY, 400 LBS.
# 4193     PAD,PREP,ALCOHOL,LARGE,2-PLY,STERILE
#
#                               Products.long_description  Products.websites  \
# 4189  <ul><li> Can be used as a sickness bag  </li><...                NaN
# 4190  <ul><li> Built to last, our Bed Assist Bar pro...                NaN
# 4191  <p>For an easily transportable scooter that co...                NaN
# 4192  <ul><li> Reinforced design to support higher w...                NaN
# 4193  <ul><li> The soft, absorbent, non-woven pads a...                NaN
#
#       Products.video  Products.audio  \
# 4189             NaN             NaN
# 4190     7tER37zvNNk             NaN
# 4191     6uBab-v_Y-I             NaN
# 4192             NaN             NaN
# 4193             NaN             NaN
#
#                                      Products.seo_title  \
# 4189  Emesis/Barf Bags, Blue - 24 Pack | Medline- NO...
# 4190  Bed Assist Bar with Storage Pocket | MEDLINE -...
# 4191  Spitfire EX Travel 4-Wheel Mobility Scooter 21...
# 4192  Standard Bariatric Heavy Duty Rollator, Burgun...
# 4193    Sterile Alcohol Prep Pads | Medline- MDS090670Z
#
#                                Products.seo_description  \
# 4189  Shop CareLineMedical.com For the Top Rated Med...
# 4190                                                NaN
# 4191                                                NaN
# 4192                                                NaN
# 4193                                                NaN
#
#                                   Products.seo_keywords  Products.seo_header  \
# 4189  barf bag, emesis bags, vomit bags, barf bags, ...                  NaN
# 4190                                                NaN                  NaN
# 4191  power scooter; electric power scooter; electri...                  NaN
# 4192                                                NaN                  NaN
# 4193                                                NaN                  NaN
#
#      Products.seo_footer                                   Products.seo_url  \
# 4189                 NaN                                  Emesis-BagsBlue-2
# 4190                 NaN                                     Bed-Assist-Bar
# 4191                 NaN  Spitfire-EX-Travel-4-Wheel-Mobility-Scooter-21...
# 4192                 NaN     Standard-Bariatric-Heavy-Duty-RollatorBurgundy
# 4193                 NaN                   Sterile-Alcohol-Prep-PadsLarge-2
#
#       Products.seo_category  Products.unit  Products.packaging  \
# 4189                    0.0             PK      24 Each / Pack
# 4190                    0.0             EA       1 Each / Each
# 4191                    0.0             EA                 NaN
# 4192                    0.0             EA       1 Each / Each
# 4193                    0.0             BX      100 Each / Box
#
#       Products.display_packaging  Products.multiple  Products.length  \
# 4189                         NaN               1 PK              NaN
# 4190                         NaN               1 EA              NaN
# 4191                         NaN                NaN             42.0
# 4192                         NaN               1 EA              NaN
# 4193                         NaN               1 BX              NaN
#
#       Products.width  Products.height  Products.rx        Products.latex  \
# 4189             NaN              NaN          NaN                   Yes
# 4190             NaN              NaN          NaN                   Yes
# 4191            20.0             35.0           No  Not Made With Natura
# 4192             NaN              NaN          NaN                   NaN
# 4193             NaN              NaN          NaN                   NaN
#
#       Products.upc                                 Products.msds_link  \
# 4189  8.843890e+11                                                NaN
# 4190  8.843890e+11                                                NaN
# 4191  8.223830e+11                                                NaN
# 4192  8.019678e+10                                                NaN
# 4193           NaN  http://www.medline.com/media/catalog/Docs/MSDS...
#
#       Products.msds_label                                  Products.lit_link  \
# 4189                  NaN                                                NaN
# 4190                  NaN                                                NaN
# 4191                  NaN  http://www.drivemedical.com/product-manuals/sp...
# 4192                  NaN  https://medline360.medline.com:443/irj/servlet...
# 4193      MSD_SDS0050.pdf                                                NaN
#
#                         Products.lit_label  \
# 4189                                   NaN
# 4190                                   NaN
# 4191                                   NaN
# 4192  c0f5b78d-301d-2f10-e1a6-95d645f3becf
# 4193                                   NaN
#
#                                          Products.hcpcs  Products.case_qty  \
# 4189  NO CODE - PRODUCT DOES NOT MEET HCPCS SPECIFIC...               24.0
# 4190  NO GOVERNMENT OR SUPPLIER HCPCS CODE VERIFICATION                1.0
# 4191                                              K0800                NaN
# 4192                                              E0149                1.0
# 4193                                              A4245              100.0
#
#       Products.markup  Products.override_markup    Products.notes  \
# 4189              NaN                       1.0               NaN
# 4190              NaN                       0.0               NaN
# 4191              NaN                       0.0               NaN
# 4192              NaN                       0.0  Listed on Ebay\r
# 4193              NaN                       0.0               NaN
#
#       Products.import_flags  Products.map_price  Products.features_title  \
# 4189                  418.0                 NaN                      NaN
# 4190                  128.0                 NaN                      NaN
# 4191                  128.0             1099.00                      NaN
# 4192                    8.0              129.99                      NaN
# 4193                    NaN                 NaN                      NaN
#
#                                       Products.warranty  Products.hygienic  \
# 4189                                                NaN                0.0
# 4190                                                NaN                0.0
# 4191  Limited Lifetime on Frame; 14 Month Limited on...                0.0
# 4192                                                NaN                0.0
# 4193                                                NaN                NaN
#
#       Products.default_quantity  Products.user_size        Products.assembly  \
# 4189                        NaN                 NaN                      NaN
# 4190                        NaN                 NaN                      NaN
# 4191                        NaN           Universal  Basic Assembly Required
# 4192                        NaN                 NaN                      NaN
# 4193                        NaN                 NaN                      NaN
#
#          Products.installation Products.shipping_length  \
# 4189                       NaN                     5.00
# 4190                       NaN                    14.60
# 4191  No Installation Required                    45.00
# 4192                       NaN                    25.25
# 4193                       NaN                     6.00
#
#      Products.shipping_width Products.shipping_height  \
# 4189                    5.00                     7.00
# 4190                    4.10                    18.00
# 4191                   20.75                    20.75
# 4192                    8.60                    23.20
# 4193                    5.25                     3.00
#
#       Products.shipping_weight Products.handling_time  \
# 4189                       NaN                    NaN
# 4190                       NaN                    NaN
# 4191                     127.0         Ships Same Day
# 4192                       NaN                    NaN
# 4193                       NaN                    NaN
#
#                                  Products.rotation_link  \
# 4189                                                NaN
# 4190                                                NaN
# 4191  https://www.drivemedical.com/power-mobility/sp...
# 4192                                                NaN
# 4193                                                NaN
#
#      Products.google_shopping_label  Products.product_option Products.size  \
# 4189                            NaN                      NaN           NaN
# 4190                            NaN                      NaN           NaN
# 4191                            NaN           21AH Batteries           NaN
# 4192                            5.0                      NaN           NaN
# 4193                            NaN                      NaN         Large
#
#      Products.material Products.arm_style  Products.leg_style  \
# 4189       Plastic Rim                NaN                 NaN
# 4190               NaN                NaN                 NaN
# 4191               NaN                NaN                 NaN
# 4192          Aluminum                NaN                 NaN
# 4193               NaN                NaN                 NaN
#
#       Products.seat_size Products.family_id Products.saved_status  \
# 4189                 NaN            PF06157                   3.0
# 4190                 NaN            PF08485                   3.0
# 4191                 NaN               PM36                   3.0
# 4192                 NaN            PF04829                   3.0
# 4193                 NaN            PF03816                   3.0
#
#       Products.freight_cost
# 4189                    NaN
# 4190                    NaN
# 4191                    NaN
# 4192                    NaN
# 4193                    NaN
#
# [5 rows x 181 columns]

# %%
df.describe().T
# Out:
#                                  count          mean           std  \
# Customers.id                    4194.0  1.796518e+03  1.065679e+03
# Customers.create_date           4194.0  1.440971e+09  1.887681e+07
# Customers.status                 101.0  0.000000e+00  0.000000e+00
# Customers.mailing               2114.0  9.796594e-01  1.411959e-01
# Customers.reminders                0.0           NaN           NaN
# Customers.tax_exempt               5.0  2.000000e-01  4.472136e-01
# Customers.account_id               3.0  7.333333e+00  5.773503e-01
# Customers.sales_rep                0.0           NaN           NaN
# Customers.rewards                  0.0           NaN           NaN
# Customers.profile_id               0.0           NaN           NaN
# Customers.last_modified         4194.0  1.450401e+09  1.021334e+07
# Customers.customer_type         3771.0  1.373641e-01  3.918417e-01
# Orders.id                       4194.0  9.142984e+03  5.276541e+03
# Orders.customer_id              4194.0  1.796518e+03  1.065679e+03
# Orders.reorder_id                 82.0  7.389159e+03  3.818085e+03
# Orders.external_id                 5.0  6.018061e+08  1.342831e+09
# Orders.sales_rep                   0.0           NaN           NaN
# Orders.subtotal                 4194.0  1.319252e+02  2.311569e+02
# Orders.tax                      3737.0  8.008376e-01  4.859280e+00
# Orders.shipping                 3999.0  7.141263e+00  4.531500e+00
# Orders.coupon_id                 882.0  2.040363e+01  1.185029e+01
# Orders.coupon_amount             882.0  9.972676e+00  1.461720e+01
# Orders.gift_id                     0.0           NaN           NaN
# Orders.gift_amount                 0.0           NaN           NaN
# Orders.fee_amount                278.0  1.475259e+01  3.275524e+01
# Orders.discount_amount           364.0  1.308668e+01  5.129665e+01
# Orders.total                    4194.0  1.371928e+02  2.228985e+02
# Orders.balance_due               351.0  4.798140e+01  2.098431e+02
# Orders.shipping_trans              0.0           NaN           NaN
# Orders.shipping_flags              0.0           NaN           NaN
# Orders.weight                      3.0  1.800000e+01  6.928203e+00
# Orders.payment_status           4189.0  2.958940e+00  3.124822e-01
# Orders.payment_date             4176.0  1.443104e+09  1.809258e+07
# Orders.payment_amount           4176.0  1.348423e+02  2.138048e+02
# Orders.purchase_order              0.0           NaN           NaN
# Orders.payment_ref                 0.0           NaN           NaN
# Orders.status                   4194.0  1.326180e+00  1.508683e+00
# Orders.placed_date              4194.0  1.443054e+09  1.814291e+07
# Orders.updated_date             4171.0  1.449607e+09  9.118822e+06
# Orders.shipped_date             3848.0  1.442167e+09  1.793374e+07
# Orders.registry_id                 0.0           NaN           NaN
# Orders.gift_message                0.0           NaN           NaN
# Orders.website                     0.0           NaN           NaN
# Orders.mailing                     0.0           NaN           NaN
# Orders.flags                       1.0  1.000000e+00           NaN
# Orders.partial_ship               96.0  1.041667e-02  1.020621e-01
# Orders.customer_type            4011.0  1.241586e-01  3.750874e-01
# Order_Items.id                  4194.0  1.115607e+04  5.802466e+03
# Order_Items.parent              4194.0  9.142984e+03  5.276541e+03
# Order_Items.product_id          4151.0  4.451426e+03  5.577392e+03
# Order_Items.attributes             0.0           NaN           NaN
# Order_Items.attribute_prices       0.0           NaN           NaN
# Order_Items.qty                 4194.0  1.858846e+00  8.821959e+00
# Order_Items.price               4194.0  6.734913e+01  9.557179e+01
# Order_Items.cost                4191.0  5.111272e+01  7.415552e+01
# Order_Items.registry_item          0.0           NaN           NaN
# Order_Items.related_id             0.0           NaN           NaN
# Order_Items.reorder_frequency     24.0  1.666667e+00  9.168313e-01
# Order_Items.account_id             0.0           NaN           NaN
# Order_Items.flags               1008.0  1.916667e+00  3.998510e-01
# Products.id                     4037.0  4.518398e+03  5.614455e+03
# Products.status                 4037.0  9.871191e-01  1.386196e+00
# Products.product_type              0.0           NaN           NaN
# Products.vendor                 4037.0  1.629676e+00  1.420626e+00
# Products.import_id              4037.0  3.400297e+00  2.248065e+00
# Products.menu_name                 0.0           NaN           NaN
# Products.list_price             4017.0  1.216833e+02  2.458561e+02
# Products.price                  4036.0  7.426604e+01  9.882978e+01
# Products.sale_price             1160.0  7.075409e+01  7.240593e+01
# Products.cost                   4037.0  5.231819e+01  7.469164e+01
# Products.flags                  2987.0  9.549465e+03  1.624690e+04
# Products.left_flag              1239.0  5.811138e+00  1.236169e+00
# Products.right_flag                0.0           NaN           NaN
# Products.last_modified          4037.0  1.462428e+09  1.586206e+06
# Products.taxable                2959.0  9.408584e-01  2.359294e-01
# Products.shopping_gtin          3130.0  2.865179e+13  1.794757e+13
# Products.shopping_flags         3917.0  6.154353e+01  5.086931e+00
# Products.amazon_type               0.0           NaN           NaN
# Products.amazon_price            592.0  8.972785e+01  8.509720e+01
# Products.google_adwords            0.0           NaN           NaN
# Products.shopping_cat           2334.0  1.990000e+02  0.000000e+00
# Products.shopzilla_cat          2334.0  2.200500e+04  0.000000e+00
# Products.qb_edit_sequence       3728.0  1.450329e+09  4.029036e+05
# Products.price_break_type          0.0           NaN           NaN
# Products.price_breaks              0.0           NaN           NaN
# Products.websites                  0.0           NaN           NaN
# Products.audio                     0.0           NaN           NaN
# Products.seo_footer                0.0           NaN           NaN
# Products.seo_category           2837.0  0.000000e+00  0.000000e+00
# Products.length                  998.0  2.129201e+01  1.933405e+01
# Products.width                   996.0  1.919118e+01  5.112954e+01
# Products.height                  996.0  1.358799e+01  1.401007e+01
# Products.upc                    2127.0  5.504591e+11  3.583533e+11
# Products.case_qty               2638.0  1.628851e+02  5.084612e+02
# Products.markup                    0.0           NaN           NaN
# Products.override_markup        2920.0  1.664384e-01  3.725375e-01
# Products.import_flags           2786.0  6.505994e+01  9.471448e+01
# Products.map_price               122.0  1.816970e+02  3.123576e+02
# Products.hygienic               2080.0  6.442308e-02  2.455641e-01
# Products.default_quantity          0.0           NaN           NaN
# Products.shipping_length        3998.0  1.720822e+01  1.050878e+01
# Products.shipping_width         3998.0  1.087275e+01  6.781847e+00
# Products.shipping_height        3998.0  1.159245e+01  1.025091e+01
# Products.shipping_weight         659.0  1.548704e+01  2.225662e+01
# Products.google_shopping_label   387.0  3.863049e+00  2.098446e+00
# Products.leg_style                 0.0           NaN           NaN
# Products.saved_status           3930.0  8.763359e-01  1.364374e+00
# Products.freight_cost              0.0           NaN           NaN
#
#                                          min           25%           50%  \
# Customers.id                    3.000000e+00  8.652500e+02  1.747500e+03
# Customers.create_date           1.386089e+09  1.427323e+09  1.446412e+09
# Customers.status                0.000000e+00  0.000000e+00  0.000000e+00
# Customers.mailing               0.000000e+00  1.000000e+00  1.000000e+00
# Customers.reminders                      NaN           NaN           NaN
# Customers.tax_exempt            0.000000e+00  0.000000e+00  0.000000e+00
# Customers.account_id            7.000000e+00  7.000000e+00  7.000000e+00
# Customers.sales_rep                      NaN           NaN           NaN
# Customers.rewards                        NaN           NaN           NaN
# Customers.profile_id                     NaN           NaN           NaN
# Customers.last_modified         1.437559e+09  1.437763e+09  1.456954e+09
# Customers.customer_type         0.000000e+00  0.000000e+00  0.000000e+00
# Orders.id                       2.300000e+01  4.258000e+03  9.641000e+03
# Orders.customer_id              3.000000e+00  8.652500e+02  1.747500e+03
# Orders.reorder_id               3.000000e+01  4.537250e+03  6.887000e+03
# Orders.external_id              6.638000e+01  1.698485e+06  1.698485e+06
# Orders.sales_rep                         NaN           NaN           NaN
# Orders.subtotal                 2.890000e+00  3.675000e+01  7.474000e+01
# Orders.tax                      0.000000e+00  0.000000e+00  0.000000e+00
# Orders.shipping                 0.000000e+00  0.000000e+00  9.950000e+00
# Orders.coupon_id                4.000000e+00  1.100000e+01  2.600000e+01
# Orders.coupon_amount            0.000000e+00  6.800000e-01  5.000000e+00
# Orders.gift_id                           NaN           NaN           NaN
# Orders.gift_amount                       NaN           NaN           NaN
# Orders.fee_amount               1.000000e-02  1.765000e+00  9.705000e+00
# Orders.discount_amount          2.000000e-02  3.430000e+00  6.710000e+00
# Orders.total                    2.890000e+00  4.411000e+01  8.051000e+01
# Orders.balance_due              0.000000e+00  0.000000e+00  0.000000e+00
# Orders.shipping_trans                    NaN           NaN           NaN
# Orders.shipping_flags                    NaN           NaN           NaN
# Orders.weight                   1.000000e+01  1.600000e+01  2.200000e+01
# Orders.payment_status           0.000000e+00  3.000000e+00  3.000000e+00
# Orders.payment_date             1.386090e+09  1.431858e+09  1.449678e+09
# Orders.payment_amount           2.890000e+00  4.401500e+01  7.999000e+01
# Orders.purchase_order                    NaN           NaN           NaN
# Orders.payment_ref                       NaN           NaN           NaN
# Orders.status                   0.000000e+00  1.000000e+00  1.000000e+00
# Orders.placed_date              1.386090e+09  1.431802e+09  1.449675e+09
# Orders.updated_date             1.438868e+09  1.440529e+09  1.450214e+09
# Orders.shipped_date             1.386103e+09  1.430999e+09  1.448039e+09
# Orders.registry_id                       NaN           NaN           NaN
# Orders.gift_message                      NaN           NaN           NaN
# Orders.website                           NaN           NaN           NaN
# Orders.mailing                           NaN           NaN           NaN
# Orders.flags                    1.000000e+00  1.000000e+00  1.000000e+00
# Orders.partial_ship             0.000000e+00  0.000000e+00  0.000000e+00
# Orders.customer_type            0.000000e+00  0.000000e+00  0.000000e+00
# Order_Items.id                  3.100000e+01  5.847250e+03  1.177000e+04
# Order_Items.parent              2.300000e+01  4.258000e+03  9.641000e+03
# Order_Items.product_id          1.000000e+00  1.009000e+03  1.867000e+03
# Order_Items.attributes                   NaN           NaN           NaN
# Order_Items.attribute_prices             NaN           NaN           NaN
# Order_Items.qty                 1.000000e+00  1.000000e+00  1.000000e+00
# Order_Items.price               1.120000e+00  2.403000e+01  4.346000e+01
# Order_Items.cost                2.800000e-01  1.620000e+01  3.250000e+01
# Order_Items.registry_item                NaN           NaN           NaN
# Order_Items.related_id                   NaN           NaN           NaN
# Order_Items.reorder_frequency   1.000000e+00  1.000000e+00  1.000000e+00
# Order_Items.account_id                   NaN           NaN           NaN
# Order_Items.flags               0.000000e+00  2.000000e+00  2.000000e+00
# Products.id                     1.000000e+00  1.012000e+03  1.867000e+03
# Products.status                 0.000000e+00  0.000000e+00  0.000000e+00
# Products.product_type                    NaN           NaN           NaN
# Products.vendor                 1.000000e+00  1.000000e+00  1.000000e+00
# Products.import_id              1.000000e+00  3.000000e+00  3.000000e+00
# Products.menu_name                       NaN           NaN           NaN
# Products.list_price             1.020000e+00  3.311000e+01  7.233000e+01
# Products.price                  1.540000e+00  2.440000e+01  4.824500e+01
# Products.sale_price             2.890000e+00  3.266000e+01  5.410000e+01
# Products.cost                   2.800000e-01  1.550000e+01  3.175000e+01
# Products.flags                  0.000000e+00  0.000000e+00  0.000000e+00
# Products.left_flag              0.000000e+00  6.000000e+00  6.000000e+00
# Products.right_flag                      NaN           NaN           NaN
# Products.last_modified          1.452269e+09  1.462370e+09  1.463163e+09
# Products.taxable                0.000000e+00  1.000000e+00  1.000000e+00
# Products.shopping_gtin          1.542161e+10  1.008020e+13  4.008020e+13
# Products.shopping_flags         0.000000e+00  6.200000e+01  6.200000e+01
# Products.amazon_type                     NaN           NaN           NaN
# Products.amazon_price           2.990000e+00  4.082000e+01  6.999000e+01
# Products.google_adwords                  NaN           NaN           NaN
# Products.shopping_cat           1.990000e+02  1.990000e+02  1.990000e+02
# Products.shopzilla_cat          2.200500e+04  2.200500e+04  2.200500e+04
# Products.qb_edit_sequence       1.442503e+09  1.450323e+09  1.450324e+09
# Products.price_break_type                NaN           NaN           NaN
# Products.price_breaks                    NaN           NaN           NaN
# Products.websites                        NaN           NaN           NaN
# Products.audio                           NaN           NaN           NaN
# Products.seo_footer                      NaN           NaN           NaN
# Products.seo_category           0.000000e+00  0.000000e+00  0.000000e+00
# Products.length                 5.000000e-01  9.000000e+00  1.600000e+01
# Products.width                  2.500000e-01  4.750000e+00  1.563000e+01
# Products.height                 1.000000e-01  2.000000e+00  6.000000e+00
# Products.upc                    8.019674e+09  8.019673e+10  7.797090e+11
# Products.case_qty               1.000000e+00  1.000000e+00  5.000000e+00
# Products.markup                          NaN           NaN           NaN
# Products.override_markup        0.000000e+00  0.000000e+00  0.000000e+00
# Products.import_flags           0.000000e+00  0.000000e+00  0.000000e+00
# Products.map_price              8.190000e+00  6.500000e+01  1.049950e+02
# Products.hygienic               0.000000e+00  0.000000e+00  0.000000e+00
# Products.default_quantity                NaN           NaN           NaN
# Products.shipping_length        0.000000e+00  9.000000e+00  1.550000e+01
# Products.shipping_width         0.000000e+00  5.700000e+00  1.000000e+01
# Products.shipping_height        0.000000e+00  4.000000e+00  8.645000e+00
# Products.shipping_weight        2.000000e-02  2.775000e+00  8.900000e+00
# Products.google_shopping_label  0.000000e+00  5.000000e+00  5.000000e+00
# Products.leg_style                       NaN           NaN           NaN
# Products.saved_status           0.000000e+00  0.000000e+00  0.000000e+00
# Products.freight_cost                    NaN           NaN           NaN
#
#                                          75%           max
# Customers.id                    2.698750e+03  3.736000e+03
# Customers.create_date           1.456955e+09  1.463418e+09
# Customers.status                0.000000e+00  0.000000e+00
# Customers.mailing               1.000000e+00  1.000000e+00
# Customers.reminders                      NaN           NaN
# Customers.tax_exempt            0.000000e+00  1.000000e+00
# Customers.account_id            7.500000e+00  8.000000e+00
# Customers.sales_rep                      NaN           NaN
# Customers.rewards                        NaN           NaN
# Customers.profile_id                     NaN           NaN
# Customers.last_modified         1.456956e+09  1.463418e+09
# Customers.customer_type         0.000000e+00  2.000000e+00
# Orders.id                       1.401175e+04  1.743700e+04
# Orders.customer_id              2.698750e+03  3.736000e+03
# Orders.reorder_id               1.083200e+04  1.620100e+04
# Orders.external_id              1.698485e+06  3.003935e+09
# Orders.sales_rep                         NaN           NaN
# Orders.subtotal                 1.399600e+02  5.163040e+03
# Orders.tax                      0.000000e+00  1.329300e+02
# Orders.shipping                 9.950000e+00  3.281000e+01
# Orders.coupon_id                3.200000e+01  4.800000e+01
# Orders.coupon_amount            1.224500e+01  1.099000e+02
# Orders.gift_id                           NaN           NaN
# Orders.gift_amount                       NaN           NaN
# Orders.fee_amount               1.125000e+01  4.490000e+02
# Orders.discount_amount          9.950000e+00  5.880400e+02
# Orders.total                    1.438550e+02  4.627950e+03
# Orders.balance_due              8.250000e+00  2.017920e+03
# Orders.shipping_trans                    NaN           NaN
# Orders.shipping_flags                    NaN           NaN
# Orders.weight                   2.200000e+01  2.200000e+01
# Orders.payment_status           3.000000e+00  3.000000e+00
# Orders.payment_date             1.457913e+09  1.463419e+09
# Orders.payment_amount           1.428100e+02  4.627950e+03
# Orders.purchase_order                    NaN           NaN
# Orders.payment_ref                       NaN           NaN
# Orders.status                   1.000000e+00  1.500000e+01
# Orders.placed_date              1.457727e+09  1.463419e+09
# Orders.updated_date             1.457976e+09  1.463422e+09
# Orders.shipped_date             1.456894e+09  1.463422e+09
# Orders.registry_id                       NaN           NaN
# Orders.gift_message                      NaN           NaN
# Orders.website                           NaN           NaN
# Orders.mailing                           NaN           NaN
# Orders.flags                    1.000000e+00  1.000000e+00
# Orders.partial_ship             0.000000e+00  1.000000e+00
# Orders.customer_type            0.000000e+00  2.000000e+00
# Order_Items.id                  1.648275e+04  2.020200e+04
# Order_Items.parent              1.401175e+04  1.743700e+04
# Order_Items.product_id          4.345500e+03  2.617500e+04
# Order_Items.attributes                   NaN           NaN
# Order_Items.attribute_prices             NaN           NaN
# Order_Items.qty                 1.000000e+00  5.000000e+02
# Order_Items.price               7.499000e+01  1.899000e+03
# Order_Items.cost                5.950000e+01  1.350000e+03
# Order_Items.registry_item                NaN           NaN
# Order_Items.related_id                   NaN           NaN
# Order_Items.reorder_frequency   2.000000e+00  4.000000e+00
# Order_Items.account_id                   NaN           NaN
# Order_Items.flags               2.000000e+00  2.000000e+00
# Products.id                     4.371000e+03  2.617500e+04
# Products.status                 3.000000e+00  5.000000e+00
# Products.product_type                    NaN           NaN
# Products.vendor                 2.000000e+00  1.100000e+01
# Products.import_id              3.000000e+00  2.100000e+01
# Products.menu_name                       NaN           NaN
# Products.list_price             1.343900e+02  8.439000e+03
# Products.price                  8.336000e+01  1.899000e+03
# Products.sale_price             1.199900e+02  6.599900e+02
# Products.cost                   5.999000e+01  1.350000e+03
# Products.flags                  3.289600e+04  9.843300e+04
# Products.left_flag              6.000000e+00  9.000000e+00
# Products.right_flag                      NaN           NaN
# Products.last_modified          1.463163e+09  1.463420e+09
# Products.taxable                1.000000e+00  1.000000e+00
# Products.shopping_gtin          4.088440e+13  5.089010e+13
# Products.shopping_flags         6.200000e+01  6.300000e+01
# Products.amazon_type                     NaN           NaN
# Products.amazon_price           1.247400e+02  7.362500e+02
# Products.google_adwords                  NaN           NaN
# Products.shopping_cat           1.990000e+02  1.990000e+02
# Products.shopzilla_cat          2.200500e+04  2.200500e+04
# Products.qb_edit_sequence       1.450337e+09  1.450712e+09
# Products.price_break_type                NaN           NaN
# Products.price_breaks                    NaN           NaN
# Products.websites                        NaN           NaN
# Products.audio                           NaN           NaN
# Products.seo_footer                      NaN           NaN
# Products.seo_category           0.000000e+00  0.000000e+00
# Products.length                 2.750000e+01  1.230000e+02
# Products.width                  2.400000e+01  9.000000e+02
# Products.height                 2.800000e+01  7.600000e+01
# Products.upc                    8.223840e+11  8.931690e+11
# Products.case_qty               6.400000e+01  5.000000e+03
# Products.markup                          NaN           NaN
# Products.override_markup        0.000000e+00  1.000000e+00
# Products.import_flags           1.280000e+02  4.180000e+02
# Products.map_price              1.550000e+02  1.899000e+03
# Products.hygienic               0.000000e+00  1.000000e+00
# Products.default_quantity                NaN           NaN
# Products.shipping_length        2.350000e+01  9.000000e+01
# Products.shipping_width         1.500000e+01  8.000000e+01
# Products.shipping_height        1.500000e+01  5.800000e+01
# Products.shipping_weight        2.100000e+01  1.750000e+02
# Products.google_shopping_label  5.000000e+00  5.000000e+00
# Products.leg_style                       NaN           NaN
# Products.saved_status           3.000000e+00  3.000000e+00
# Products.freight_cost                    NaN           NaN
